# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
import os

# %%
import pandas as pd

# %%
x = os.listdir('images/')

# %%
df = pd.read_csv('lymph_dataset.csv')

# %%
df
# Out:
#      Unnamed: 0                                               data  \
# 0             0  [[[213 183 248]\r\n  [198 167 234]\r\n  [159 1...
# 1             1  [[[245 246 242]\r\n  [245 246 242]\r\n  [245 2...
# 2             2  [[[224 198 214]\r\n  [105  94 110]\r\n  [171 1...
# 3             3  [[[244 236 236]\r\n  [244 235 238]\r\n  [243 2...
# 4             4  [[[183 103 162]\r\n  [184 101 163]\r\n  [146  ...
# ..          ...                                                ...
# 930         930  [[[200 118 183]\r\n  [194 126 179]\r\n  [231 1...
# 931         931  [[[185  98 172]\r\n  [174  86 156]\r\n  [163  ...
# 932         932  [[[174  74 140]\r\n  [165  60 123]\r\n  [152  ...
# 933         933  [[[251 253 253]\r\n  [246 249 253]\r\n  [207 2...
# 934         934  [[[ 46   0  24]\r\n  [ 81  29  59]\r\n  [ 96  ...
#
#                                          file  status
# 0    00001b2b5609af42ab0ab276dd4cd41c3e7745b5       1
# ...

# %%
img =cv.imread('images/00e77bde04dded4f9cc688a18d1f90c7ac4c2be4.tif')
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
figure,axis = plt.subplots(1,4,figsize=(12,12))

image = cv.imread('images/00e77bde04dded4f9cc688a18d1f90c7ac4c2be4.tif')
image_blurred = cv.GaussianBlur(image, (0, 0), 3)
image_color = cv.cvtColor(image,cv.COLOR_BGR2HSV)
image_edges = cv.Canny(image_color,30,200)
image_sharp = cv.addWeighted(image, 1.5, image_blurred, -0.5, 0)
axis[0].imshow(image_edges)
axis[1].imshow(image_color)
axis[2].imshow(image_blurred)
axis[3].imshow(image_sharp)

# %%
image_color = cv.cvtColor(image,cv.COLOR_BGR2HSV)
plt.title('POSITIVE')
plt.imshow(image_color)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img =cv.imread('images/00a01a16ea56bcc9463351b6a5c3ca0fb0bf114c.tif')
image_color = cv.cvtColor(img,cv.COLOR_BGR2HSV)
plt.title('NEGATIVE')
plt.imshow(image_color)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img =cv.imread('images/00a01a16ea56bcc9463351b6a5c3ca0fb0bf114c.tif')
# image_color = cv.cvtColor(img,cv.COLOR_BGR2HSV)
plt.title('NEGATIVE')
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np

# %%
# white_threshold = 200 #130
lower_white = np.array([189, 197, 214], dtype=np.uint8)
upper_white = np.array([190, 198, 215], dtype=np.uint8)
white_mask = cv.inRange(img, lower_white, upper_white)
white_image = cv.bitwise_and(image_color, image_color, mask=white_mask)

# %% [markdown]
# the above code is not good to use

# %%
lower_white = np.array([31, 0, 37], dtype=np.uint8)
upper_white = np.array([72, 25, 63], dtype=np.uint8)
white_mask = cv.inRange(img, lower_white, upper_white)
white_image = cv.bitwise_and(image_color, image_color, mask=white_mask)

# %%
plt.imshow(white_image)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imshow(white_image)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
